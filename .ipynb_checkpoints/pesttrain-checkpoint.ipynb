# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.layers import Dense, Flatten, BatchNormalization, Dropout
from keras.applications import InceptionV3
from glob import glob

# %% [markdown]
# ## Loading Data

# %%
train_path = "train"
test_path = "test"
validation_path = "valid"

# %% [markdown]
# ## Vısualization

# %%
img = load_img(train_path + "/ants/001.jpg")
plt.imshow(img)
plt.axis("off")
plt.title("Sample Ants Image")
plt.show()

plt.figure()

img = load_img(train_path + "/bees/018.jpg")
plt.imshow(img)
plt.axis("off")
plt.title("Sample Bees Image")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 img = load_img(train_path + "/ANHINGA/001.jpg")
#       2 plt.imshow(img)
#       3 plt.axis("off")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\image_utils.py:422, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420     if isinstance(path, pathlib.Path):
#     421         path = str(path.resolve())
# --> 422     with open(path, "rb") as f:
#     423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train/ANHINGA/001.jpg'

# %%
fig, axs = plt.subplots(2, 2, figsize=(8, 8))
axs[0,0].imshow(load_img(train_path + "/BARN OWL/018.jpg"))
axs[0,0].axis("off")

axs[0,1].imshow(load_img(train_path + "/ALBATROSS/001.jpg"))
axs[0,1].axis("off")

axs[1,0].imshow(load_img(train_path + "/CANARY/107.jpg"))                        
axs[1,0].axis("off")

axs[1,1].imshow(load_img(train_path + "/CROW/100.jpg"))
axs[1,1].axis("off")

plt.show()

# %% [markdown]
# ## Data Processing

# %%
className = glob(train_path + "/*")
NumberofClass = len(className)
print("NumberofClass:", NumberofClass)
# Out:
# NumberofClass: 285

# %%
train_datagen = ImageDataGenerator(rescale=1/255)
validation_datagen=ImageDataGenerator(rescale=1/255)
test_datagen=ImageDataGenerator(rescale=1/255)

# %% [markdown]
# ## Data Augmentation

# %%
batch_size = 256
train_datagen = ImageDataGenerator(rescale=1/255,
                  shear_range=0.3,
                  horizontal_flip=True,
                  zoom_range=0.3
                  )
val_datagen = ImageDataGenerator(rescale=1/255)

train_generator = train_datagen.flow_from_directory(
                train_path,
                target_size=(224,224),
                batch_size=batch_size,
                color_mode="rgb",
                class_mode="categorical"
                )

val_generator = val_datagen.flow_from_directory(
                validation_path,
                target_size=(224,224),
                batch_size=batch_size,
                color_mode="rgb",
                class_mode="categorical"
                )
# Out:
# Found 40930 images belonging to 285 classes.
# Found 1425 images belonging to 285 classes.

# %% [markdown]
# ## InceptionV3 Model

# %%
IncV3 = InceptionV3(include_top = False, weights = "imagenet",input_shape = (224,224,3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step

# %%
model = Sequential()

model.add(IncV3)
    
for layer in model.layers:
    layer.trainable = False


model.add(Flatten())

model.add(Dense(units = 2048, activation = "relu"))
model.add(Dropout(0.5))
model.add(Dense(units = NumberofClass, activation = "softmax"))

# %% [markdown]
# ## Compiling the Model

# %%
model.compile(optimizer = "adam", loss = "categorical_crossentropy", metrics = ["accuracy"])

# %% [markdown]
# ## Fitting

# %%
history = model.fit(train_generator,
                    validation_data = val_generator,
                    epochs = 5,
                    batch_size = batch_size)
# Out:
# Epoch 1/5
# 160/160 [==============================] - 2713s 17s/step - loss: 9.1888 - accuracy: 0.1333 - val_loss: 1.8328 - val_accuracy: 0.5684
# Epoch 2/5
# 160/160 [==============================] - 2689s 17s/step - loss: 2.7871 - accuracy: 0.3441 - val_loss: 1.1811 - val_accuracy: 0.6975
# Epoch 3/5
# 160/160 [==============================] - 2689s 17s/step - loss: 2.3810 - accuracy: 0.4124 - val_loss: 1.0394 - val_accuracy: 0.7151
# Epoch 4/5
# 160/160 [==============================] - 2681s 17s/step - loss: 2.2037 - accuracy: 0.4482 - val_loss: 0.8846 - val_accuracy: 0.7382
# Epoch 5/5
# 160/160 [==============================] - 2678s 17s/step - loss: 2.0798 - accuracy: 0.4708 - val_loss: 0.8361 - val_accuracy: 0.7593

# %% [markdown]
# ## Evaluating the Model

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.show()
